# %% [markdown]
# # AMMI NLP - Part 1
# ## Lab 1: Introduction to text classification

# %% [markdown]
# ### Section 1: Text Classification with Naive Bayes Classifier

# %% [markdown]
# In this part you'll implement naive Bayes classifier to classify the text.
# you need to build a model that predicts the langauge of the text given the words of the text

# %%
import io, sys, math, re
from collections import defaultdict

# %%
def load_data(filename):
    fin = io.open(filename, 'r', encoding='utf-8')
    data = []
    for line in fin:
        tokens = line.split()
        data.append((tokens[0], tokens[1:]))
    return data

# %%
data = load_data("train1.txt")
data[0]
# Tuple of (string, [list of strings])
# Out:
# ('__label__deu',
#  ['Ich', 'würde', 'alles', 'tun,', 'um', 'dich', 'zu', 'beschützen.'])

# %%
def count_words(data):
    ''' 
    This function should return the counts described below:
    # label_counts = dic {label: value =  no. of times the label appeared }
    # word_counts = dictionary of dictionaries
     {label: {word: no. of times word appeared within this label }}
    # label_total: total number of labels. (size of train data)
    # word_total: total number of words in for a given label
     dic {label: no.of words}
    
    '''
    label_total = 0
    word_total = defaultdict(lambda: 0)
    label_counts = defaultdict(lambda: 0)
    word_counts = defaultdict(lambda: defaultdict(lambda: 0.0))

    for example in data:
        label, sentence = example
        ## FILL CODE


    return {'label_counts': label_counts, 
            'word_counts': word_counts, 
            'label_total': label_total, 
            'word_total': word_total}

# %%
# label_counts = {dic key =label: value =  no. of times the label appeared }
# word_counts = dictionary of dictionaries
# {label: {word: no. of times word appeared within this label }}
# label_total: total number of labels. (size of train data)
# word_total: total number of words in for a given label
# dic {label: no.of words}
# Out:
# {'label_counts': defaultdict(<function __main__.count_words.<locals>.<lambda>>,
#              {'__label__deu': 828.0,
#               '__label__eng': 2137.0,
#               '__label__epo': 1020.0,
#               '__label__fra': 650.0,
#               '__label__hun': 432.0,
#               '__label__ita': 1327.0,
#               '__label__por': 578.0,
#               '__label__rus': 1271.0,
#               '__label__spa': 564.0,
#               '__label__tur': 1193.0}),
#  'label_total': 10000.0,
#  'word_counts': defaultdict(<function __main__.count_words.<locals>.<lambda>>,
#              {'__label__deu': defaultdict(<function __main__.count_words.<locals>.<lambda>.<locals>.<lambda>>,
#                           {'Ich': 140.0,
#                            'würde': 9.0,
#                            'alles': 6.0,
#                            'tun,': 1.0,
#                            'um': 22.0,
#                            'dich': 15.0,
#                            'zu': 78.0,
# ...

# %%
def predict(sentence, mu, label_counts, word_counts, label_total, word_total):
    best_label = None
    best_score = float('-inf')

    for label in word_counts.keys():
        score = 0.0
        ## FILL CODE

    return best_label

# %%
def compute_accuracy(valid_data, mu, counts):
    accuracy = 0.0
    for label, sentence in valid_data:
         ## FILL CODE
            pass 
    return 0.0

# %%
print("")
print("** Naive Bayes **")
print("")

mu = 1.0
train_data = load_data("train1.txt")
valid_data = load_data("valid1.txt")
counts = count_words(train_data)

print("Validation accuracy: %.3f" % compute_accuracy(valid_data, mu, counts))
print("")
# Out:
# ** Naive Bayes **
#
# Validation accuracy: 0.000
